# %%
import os  
import pandas as pd

# %%
import pandas as pd
from IPython.display import display

# Define file path
file_path = r"C:\Users\Pinda\Downloads\mort2023ps\VS23MORT.DPSMCPUB_r20241030"

# Define colspecs and column names
colspecs = [
    (68, 69),     # Sex
    (83, 84),     # Place of death
    (84, 85),     # Marital Status
    (85, 86),     # Day of Week of Death
    (106, 107),   # Injury at Work
    (107, 108),   # Manner of Death
    (108, 109),   # Method of Disposition
    (109, 110),   # Autopsy
    (144, 145),   # Activity Code
    (145, 146),   # Place of Injury
    (146, 150),   # ICD-10 Cause of Death
    (154, 157),   # 113 Cause Recode
    (450, 451),   # Race Recode 6
    (484, 487),   # Hispanic Origin
    (487, 489),   # Hispanic Origin / Race Recode
]

column_names = [
    'Sex', 'PlaceOfDeath', 'MaritalStatus', 'DayOfWeek',
    'InjuryAtWork', 'MannerOfDeath', 'DispositionMethod', 'Autopsy',
    'ActivityCode', 'PlaceOfInjury', 'ICD10Cause', 'Cause113Recode',
    'RaceRecode6', 'HispanicOrigin', 'HispanicRaceRecode'
]

# Load data sample
df = pd.read_fwf(file_path, colspecs=colspecs, names=column_names, nrows=10000)

# Display first 20 rows nicely
display(df.head(20)) 

df.to_csv("mortality_stats.csv")
# Out:
#    Sex PlaceOfDeath  MaritalStatus  DayOfWeek  InjuryAtWork MannerOfDeath  \
# 0    F            W              3        NaN           7.0             B
# 1    F            S              3        NaN           7.0             B
# 2    M            W              1        NaN           7.0             B
# 3    M            M              2        NaN           7.0             C
# 4    F            W              4        NaN           7.0             B
# 5    M            M              4        NaN           7.0             B
# 6    M            D              5        NaN           2.0             B
# 7    F            W              7        NaN           7.0             B
# 8    F            M              1        NaN           7.0             C
# 9    F            U              2        NaN           7.0             B
# 10   M            M              2        NaN           7.0             C
# 11   M            M              4        NaN           7.0             B
# ...
